# %% [markdown]
# Name: Ibrahim Al Hazwani

# %%
# Importing the library

import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Create a variable for where the dataset is saved

path = '../Data/iris.data.head.csv'

# %% [markdown]
# **Task one**: load the iris data set

# %%
# Read the data usign pandas

df = pd.read_csv(path)

# %%
# showing the dataset

df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width           class
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# **Task two**: plot the histograms of all the variables/features (=columns)

# %%
plt.hist(df['sepal_length'])
plt.title('sepal_length')
plt.xlabel('value')
plt.ylabel('frequency')
plt.grid()
plt.show()

# %%
plt.hist(df['sepal_width'],bins=20)
plt.title('sepal_width')
plt.xlabel('value')
plt.ylabel('frequency')
plt.grid()
plt.show()

# %%
plt.hist(df['petal_length'],bins=20)
plt.title('petal_length')
plt.xlabel('value')
plt.ylabel('frequency')
plt.grid()
plt.show()

# %%
plt.hist(df['petal_width'],bins=20)
plt.title('petal_width')
plt.xlabel('value')
plt.ylabel('frequency')
plt.grid()
plt.show()

# %% [markdown]
# **Task three**: choose the right normalization technique for each variable and normalize it

# %%
# create variables fro the sepal length and width

sepal_length = df['sepal_length']
sepal_width = df['sepal_width']

# %%
# create variables fro the petal length and width

petal_length = df['petal_length']
petal_width = df['petal_width']

# %%
# standarize of the sepal lenght and the petal width variables

sepal_length_stand = (sepal_length - np.mean(sepal_length))/np.std(sepal_length)
petal_width_stand = (petal_width - np.mean(petal_width))/np.std(petal_width)

# %%
# normalization of the sepal width and the petal lenght variables

sepal_width_norm = (sepal_width - min(sepal_width))/(max(sepal_width) - min(sepal_width))
petal_length_norm = (petal_length - min(petal_length))/(max(petal_length) - min(petal_length))

# %% [markdown]
# **Task four**: make 2D plot

# %%
# create a new dataset called df2 with the new variables

df2 = pd.DataFrame(dict(sepal_lenght_std = sepal_length_stand,sepal_width_norm = sepal_width_norm, \
                        petal_lenght_norm = petal_length_norm, petal_width_std = petal_width_stand, type_of = df['class']),
                   columns= ['sepal_lenght_std','sepal_width_norm','petal_lenght_norm','petal_width_std','type_of'])

# %%
# creating a new variables for each type of iris

iris_setosa_df = df2.loc[df2['type_of']=='Iris-setosa']
iris_versicolor_df = df2.loc[df2['type_of']=='Iris-versicolor']
iris_virginica_df = df2.loc[df2['type_of']=='Iris-virginica']

# %%
# plotting using scatter sepal_lenght_std - sepal_width_norm

plt.scatter(iris_setosa_df['sepal_lenght_std'], iris_setosa_df['sepal_width_norm'])
plt.scatter(iris_versicolor_df['sepal_lenght_std'], iris_versicolor_df['sepal_width_norm'])
plt.scatter(iris_virginica_df['sepal_lenght_std'], iris_virginica_df['sepal_width_norm'])

plt.xlabel('sepal_lenght_std')
plt.ylabel('sepal_width_norm')
plt.title('sepal_lenght_std - sepal_width_norm')
plt.legend(title = 'type',
           colors = ['red','pink']
           labels=['iris-setosa','iris-versicolor','iris-virginica'],
           loc='center left', bbox_to_anchor=(1, 0.5))

plt.show()

# %%
# plotting using scatter sepal_lenght_std - petal_lenght_norm

plt.scatter(iris_setosa_df['sepal_lenght_std'], iris_setosa_df['petal_lenght_norm'])
plt.scatter(iris_versicolor_df['sepal_lenght_std'], iris_versicolor_df['petal_lenght_norm'])
plt.scatter(iris_virginica_df['sepal_lenght_std'], iris_virginica_df['petal_lenght_norm'])

plt.xlabel('sepal_lenght_std')
plt.ylabel('petal_lenght_norm')
plt.title('sepal_lenght_std - petal_lenght_norm')
plt.legend(title = 'type',
           labels=['iris-setosa','iris-versicolor','iris-virginica'],
           loc='center left', bbox_to_anchor=(1.0, 0.5))

plt.show()

# %%
# plotting using scatter sepal_lenght_std - petal_width_std


plt.scatter(iris_setosa_df['sepal_lenght_std'], iris_setosa_df['petal_width_std'])
plt.scatter(iris_versicolor_df['sepal_lenght_std'], iris_versicolor_df['petal_width_std'])
plt.scatter(iris_virginica_df['sepal_lenght_std'], iris_virginica_df['petal_width_std'])

plt.xlabel('sepal_lenght_std')
plt.ylabel('petal_width_std')
plt.title('sepal_lenght_std - petal_width_std')
plt.legend(title = 'type',
           labels=['iris-setosa','iris-versicolor','iris-virginica'],
           loc='center left', bbox_to_anchor=(1.0, 0.5))

plt.show()

# %%
# plotting using scatter sepal_width_norm - petal_lenght_norm

plt.scatter(iris_setosa_df['sepal_width_norm'], iris_setosa_df['petal_lenght_norm'])
plt.scatter(iris_versicolor_df['sepal_width_norm'], iris_versicolor_df['petal_lenght_norm'])
plt.scatter(iris_virginica_df['sepal_width_norm'], iris_virginica_df['petal_lenght_norm'])

plt.xlabel('sepal_width_norm')
plt.ylabel('petal_lenght_norm')
plt.title('sepal_width_norm - petal_lenght_norm')
plt.legend(title = 'type',
           labels=['iris-setosa','iris-versicolor','iris-virginica'],
           loc='center left', bbox_to_anchor=(1.0, 0.5))

plt.show()

# %%
# plotting using scatter sepal_width_norm - petal_width_std

plt.scatter(iris_setosa_df['sepal_width_norm'], iris_setosa_df['petal_width_std'])
plt.scatter(iris_versicolor_df['sepal_width_norm'], iris_versicolor_df['petal_width_std'])
plt.scatter(iris_virginica_df['sepal_width_norm'], iris_virginica_df['petal_width_std'])

plt.xlabel('sepal_width_norm')
plt.ylabel('petal_width_std')
plt.title('sepal_width_norm - petal_width_std')
plt.legend(title = 'type',
           labels=['iris-setosa','iris-versicolor','iris-virginica'],
           loc='center left', bbox_to_anchor=(1.0, 0.5))

plt.show()

# %%
# plotting using scatter petal_lenght_norm - petal_width_std

plt.scatter(iris_setosa_df['petal_lenght_norm'], iris_setosa_df['petal_width_std'])
plt.scatter(iris_versicolor_df['petal_lenght_norm'], iris_versicolor_df['petal_width_std'])
plt.scatter(iris_virginica_df['petal_lenght_norm'], iris_virginica_df['petal_width_std'])

plt.xlabel('petal_lenght_norm')
plt.ylabel('petal_width_std')
plt.title('petal_lenght_norm - petal_width_std')
plt.legend(title = 'type',
           labels=['iris-setosa','iris-versicolor','iris-virginica'],
           loc='center left', bbox_to_anchor=(1.0, 0.5))

plt.show()

# %% [markdown]
# The same result could be also reach using the *seaborn* library.
# Here below an example.

# %%
import seaborn as sns

# %%
sns.scatterplot(df2['sepal_lenght_std'], df2['sepal_width_norm'], hue = df2['type_of'], legend='brief')

plt.legend(loc='center left', bbox_to_anchor=(1.0, 0.5))
plt.show()
